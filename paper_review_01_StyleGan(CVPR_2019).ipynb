# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 위 ppt 이미지 출처 : 유튜브 나동빈
# (https://www.youtube.com/watch?v=HXgfw3Z5zRo&list=WL&index=43)

# %% [markdown]
# 1. disentanglement 특성에 따라 다양한 연출이 가능하다는 장점이 크다.
# 2. 다양한 스타일들을 구분하고, 구분된 각 스타일들을 다르게 적용시킬 수 있다는 장점을 가지고 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ㄴ 관련연구 1 : DCGAN에서의 벡터 연산(Vector Arithmetic)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ㄴ 관련 연구 2 :PGGAN
# 다양한 특징들이 구분되지 않았기 때문에 이미지의 특징을 제어하기 어려운 한계가 발생

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
